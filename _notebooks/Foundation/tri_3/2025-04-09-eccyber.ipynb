# %% [raw]
# ---
# toc: true
# comments: false
# layout: post
# title: Extra Credit - Cyber Security Panel
# permalink: /excyber/
# type: ccc
# ---

# %% [markdown]
# RensWare (lensware?) - good oppurtunity
# # Cybersecurity Landscape
# ## What are some of the biggest CS threats today and what are ways to prevent them?
# - Ransomware: all data is encrypted and one pays money to have the decrypt it.
# - data is being stolen, their information, designs, intellectual creations, etc.
# - AI - ransomeware, redistributing things
# - we need more ethical hackers
# - phishing - many ppl who don't know the basics of security, even those w experience, with protection, still click on links and get stuff hacked
# - 0 day - vulnerability that has no patch
#     - microsoft w cloud updates don't check -> smone adds bad code (iforogtthewordd) and it gets spread to everyone
#
# ## How do ethical hackets help + strength orgs? What r sm ethical concerns?
# - home security - get a real burgler to break in to test it
# - backdoor - unprofess way into security system
#
# # Career Oppurtunities
# ## How did u get into this field?
# - in the past, cs/computing was the future
# - quanico ..?
# - international
# - anyone can learn it if they put their mind to it
# - getting certifications
#
# ## What should stu do rn to get into cyber
# - Good foundation in IT
# - do CS
# - Soft skills - ppl should know u, like u, be a good person, it'll get u further
# - curious, passionate, likable, technical
# - build ur own network (like digital) - and hack ur own
# - intern
# - learn w real world scenarios
#
# ## What was ur biggest obstacle u faced and how has it impacted u?
# - business - convincing to push money/invest into security (dump it down to nontechnical jargon and others know the value in what ur proposing)
# - being ignorant
# - not having a background in this and getting thrown in this (flouished the best this way for him personally)
# - figuring out how to get things accomplished w less resources e.g. less ppl
#
# # Future of Cyber Security
# ## what trends r u anticipating for the next 5 to 10 yrs and how will it affect the job market
# - more specialization e.g. healthcare IT
# - AI - takes job away from coders
# - kor, chn, smth, etc, r rly skilled and will need to be fought back
# - all entitys will be hiring + prioritizing Cybersecurity - seen in big corps, in med to small companies either only 1 or few or none
# - ppl don't know how to secure code
#
# ## how do cybersec ppl continue to evolve to persisting threats?
# - new stuff comes out all the time, staying in the know about what is happening, what other countires r doing, etc
# - reading a lot of stuff
# - a network of ppl - identify a network of ppl rly good, learn from them, work w them, they'll teach u a lot, find u jobs, etc
# - stay update in tech, tools, etc
# - like a sports team - idk / i forgot that he meant by this
#
#
# cc (certified cybersecurity) from isc2
# foundation stuff for network, IT
# A+ and N+ and smth+
# ^computing, ^networking
#
# working as a group is impt, you'll come accoss ppl u hate, u still have to work w them
# working w others is group + impt
#
# bridge btwn application + theoretical
# more theoretical stuff is toooooo complication to get off the ground
# 0 day stuff gets off the ground rly quickly tho
#
# cyberceo club meetings: mondays at lunch in morts room.
#
# # key learnings, personal takeaways, what u got out of this
# - **Cybersecurity is everywhere** — from major corporations to small businesses, everyone needs it. The threat landscape is evolving rapidly with ransomware, phishing, AI-based attacks, and 0-day vulnerabilities.
# - **People are still the weakest link** — even experienced professionals fall for phishing. This shows the importance of continual education and awareness.
# - **Ethical hackers are essential** — like hiring a burglar to test your home security, organizations need ethical hackers to find and fix weaknesses before real attackers do.
# - **Soft skills matter just as much as technical ones** — being likable, curious, and collaborative can open doors and help build trust when advocating for security investments.
# - **You don’t need a traditional background** — many professionals came into cybersecurity from unrelated fields or without formal degrees. What matters most is passion, adaptability, and a willingness to learn.
# - **Certifications help** — foundational certs like A+, Network+, and Certified Cybersecurity (ISC2) are great entry points.
# - **Build your own digital footprint** — create, break, and rebuild your own systems to learn hands-on. Internships, real-world projects, and networking will take you far.
# - **The future is specialized** — expect more focused roles in areas like healthcare IT, secure software, and threat intelligence.
# - **Always stay in the loop** — cybersecurity pros read constantly, learn from their network, and adapt to new threats like a tight-knit sports team.
# - **You’ll face obstacles** — whether it’s lack of resources, skeptical execs, or team conflicts, being able to communicate clearly and push forward is key.
# - It is important to put yourself out there and to contantly improve your skills. This includes technical and soft skills.
